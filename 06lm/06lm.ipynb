# %%
api_key = "AIzaSyBCATyuTZx9rz3SBZqn38YC201O3z9b634"

# %%
import os
from google import genai

# Configura tu API Key
client = genai.Client(api_key=api_key)

# Realiza la consulta utilizando el modelo estándar de Gemini
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Cuándo son las matrículas?',
)

print(response.text)
# Out:
# Las fechas de matrícula varían **mucho** dependiendo de varios factores:
#
# 1.  **Tipo de institución:** No es lo mismo una universidad, un colegio, un centro de formación profesional, una escuela de idiomas, etc.
# 2.  **País y región:** Cada sistema educativo tiene su propio calendario.
# 3.  **Ciclo académico:** Si es para el inicio del curso (normalmente en otoño), para el segundo semestre, para un curso de verano, etc.
# 4.  **Nuevo ingreso o continuación de estudios:** Los plazos pueden ser diferentes para estudiantes nuevos que para los que ya están en la institución.
# 5.  **Tipo de estudios:** Grados, másteres, doctorados, cursos de especialización, etc.
#
# **Sin embargo, puedo darte una idea general para los sistemas educativos más comunes (como en España o muchos países de Latinoamérica para el curso que empieza en otoño):**
#
# *   **Universidades y Formación Profesional (FP) para el curso que empieza en otoño (septiembre/octubre):**
# ...

# %%
contents = ['En mi facultad tenemos 4 carreras, la carrera de ingeniería en computación, ingeniería en software, ingeniería en ciencia de datos e ingeniería en sistemas de información.',
            'Las matrículas para el próximo semestre comienzan el 1 de julio y terminan el 15 de julio. Es importante que los estudiantes completen su proceso de matrícula dentro de este período para asegurar su lugar en las clases.',
            'Las matrículas para computación y software son del 1 al 5 de julio, mientras que para ciencia de datos y sistemas de información son del 6 al 10 de julio.',
            'Para los estudiantes especiales las matrículas son del 11 al 15 de julio.',
            'Cuándo son las matrículas?']

# %%
# Realiza la consulta utilizando el modelo estándar de Gemini
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=contents
)

print(response.text)
# Out:
# Aquí tienes el resumen de las fechas de matrícula:
#
# Las matrículas para el próximo semestre son del **1 de julio al 15 de julio**.
#
# Desglose por categoría:
#
# *   **Ingeniería en Computación e Ingeniería en Software:** Del **1 de julio al 5 de julio**.
# *   **Ingeniería en Ciencia de Datos e Ingeniería en Sistemas de Información:** Del **6 de julio al 10 de julio**.
# *   **Estudiantes especiales:** Del **11 de julio al 15 de julio**.
#
# ¡Asegúrate de matricularte dentro de tu período correspondiente!
